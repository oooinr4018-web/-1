# %% [markdown]
# <a href="https://colab.research.google.com/github/oooinr4018-web/-1/blob/main/ESAA_0525_%EC%88%98%EC%83%81%EC%9E%91%EB%A6%AC%EB%B7%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 주제
#
# Kaggle Orbit Wars 게임에서 행성을 점령하는 AI Agent 구현
#
# # 데이터
# - orbit_wars 환경 사용
#
# - 관측값: 플레이어 ID, 행성 정보, 함대 정보, 각속소
#
# - 행성 정보: 소유자, 위치, 반지름, 보유 함선 수, 생산량
#
# - 에이전트는 [출발 행성 id, 각도, 보낼 함선 수] 형태로 행동 반환
#
# # 코드 흐름
#
# - 내 행성과 공격 대상 행성 분리
#
# - 각 내 행성마다 가장 가까운 적/중립 행성 탐색
#
# - 거리 계산 후 최소 거리 행성 선택
#
# - 목표 행성의 함선 수보다 많은 함선이 있을 때만 공격
#
# - atan2로 공격 각도 계산 후 move에 추가

# %%
my_planets = [p for p in planets if p.owner == player]
targets = [p for p in planets if p.owner != player]

dist = math.sqrt((mine.x - t.x)**2 + (mine.y - t.y)**2)
angle = math.atan2(nearest.y - mine.y, nearest.x - mine.x)

moves.append([mine.id, angle, ships_needed])

# %% [markdown]
# # 새롭게 알게 된 내용
#
# - 게임 AI는 단순 예측 모델이 아니라, 현재 상태를 읽고 행동을 결정하는 전략 함수로 구현된다.
#
# - math.sqrt는 행성 간 거리를 계산하고, math.atan2로 방향 각도를 구해 함대를 보낸다.
#
# - 단순히 가까운 행성을 공격하는 전력은 구현은 쉽지만 한계가 있다.
#
# # 어려운 점 / 한계
#
# - 이동 시간동안 상대 행성이 함선을 계속 생산하는 점을 고려하지 못한다.
#
# - 여러 내 행성이 같은 목표를 중복 공격할 수 없다.
#
# - 중앙 태양을 지나가는 경로는 함대가 파괴될 수 있는데 이를 고려하지 않는다.
#
# - 가까운 목표가 없을 때 함선을 효율적으로 모으는 전략이 부족하다.
